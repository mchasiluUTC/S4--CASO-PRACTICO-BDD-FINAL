# %% [markdown]
# # S4- CASO PRACTICO-BDD FINAL
#
# ### Participantes GRUPO 3:
#
# - Juan José Cabrera
# - Marco Vinicio Chasiluisa
# - Luis Felipe Contreras
# - Ana Belén Erazo

# %% [markdown]
# ### 1. Importe la base de datos a una base en Jupyter Notebook con pandas.

# %%
# !pip install linearmodels
# Out:
# Requirement already satisfied: linearmodels in /Users/belen/anaconda3/lib/python3.11/site-packages (5.4)
# Requirement already satisfied: numpy>=1.22.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (1.24.3)
# Requirement already satisfied: pandas>=1.3.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (2.0.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (1.11.1)
# Requirement already satisfied: statsmodels>=0.12.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.4 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=0.29.37 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (3.0.9)
# Requirement already satisfied: pyhdfe>=0.1 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=0.6.5 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (1.0.1)
# Requirement already satisfied: setuptools-scm[toml]<9.0.0,>=8.0.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from linearmodels) (8.0.4)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (4.7.1)
# Requirement already satisfied: wrapt>=1.0 in /Users/belen/anaconda3/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/belen/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/belen/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->linearmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/belen/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->linearmodels) (2023.3)
# Requirement already satisfied: packaging>=20 in /Users/belen/anaconda3/lib/python3.11/site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (23.1)
# Requirement already satisfied: setuptools in /Users/belen/anaconda3/lib/python3.11/site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (68.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/belen/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.12.0->linearmodels) (0.5.3)
# Requirement already satisfied: six in /Users/belen/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.12.0->linearmodels) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Para la regresión y validación de supuestos llamamos a statsmodel, el módulo encargado de la notación de fórmula y al módulo para las pruebas de hipótesis.

# %%
import statsmodels.stats.api as sms
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.compat import lzip

# %% [markdown]
# Ahora ,  llamemos a nuestra base de datos a nuestro espacio en el Jupyer Notebook:

# %%
df=pd.read_csv("/Users/belen/Documents/GitHub/S4-CASOPRACTICO-BDDFINAL/Walmart.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %% [markdown]
# #### Recodificar el nombre de las columnas a español

# %%
df.rename({ 'Store':'tienda', 'Date': 'fecha', 'Weekly_Sales':'ventas_semanales', 'Holiday_Flag': 'flag_feriado', 'Temperature':'temperatura', 'Fuel_Price': 'precio_combustible', 'CPI': 'CPI', 'Unemployment': 'desempleo'  }, axis=1, inplace=True)

# %% [markdown]
# Se separa el campo de fecha para poder categorizar las ventas por año.

# %%
df[['dia', 'mes', 'anio']] = df['fecha'].str.split('-', expand=True)
df
# Out:
#       tienda       fecha  ventas_semanales  flag_feriado  temperatura  \
# 0          1  05-02-2010        1643690.90             0        42.31
# 1          1  12-02-2010        1641957.44             1        38.51
# 2          1  19-02-2010        1611968.17             0        39.93
# 3          1  26-02-2010        1409727.59             0        46.63
# 4          1  05-03-2010        1554806.68             0        46.50
# ...      ...         ...               ...           ...          ...
# 6430      45  28-09-2012         713173.95             0        64.88
# 6431      45  05-10-2012         733455.07             0        64.89
# 6432      45  12-10-2012         734464.36             0        54.47
# 6433      45  19-10-2012         718125.53             0        56.47
# 6434      45  26-10-2012         760281.43             0        58.85
#
#       precio_combustible         CPI  desempleo dia mes  anio
# 0                  2.572  211.096358      8.106  05  02  2010
# 1                  2.548  211.242170      8.106  12  02  2010
# 2                  2.514  211.289143      8.106  19  02  2010
# 3                  2.561  211.319643      8.106  26  02  2010
# 4                  2.625  211.350143      8.106  05  03  2010
# ...                  ...         ...        ...  ..  ..   ...
# 6430               3.997  192.013558      8.684  28  09  2012
# 6431               3.985  192.170412      8.667  05  10  2012
# 6432               4.000  192.327265      8.667  12  10  2012
# 6433               3.969  192.330854      8.667  19  10  2012
# 6434               3.882  192.308899      8.667  26  10  2012
#
# [6435 rows x 11 columns]

# %% [markdown]
# Se hace el nivel de desempleo como una variable categorica para ver de mejor manera la tasa de desempleo.

# %%
# Definir una función para asignar el valor según la comparación
def asignar_valor(valor):
    if valor < 6.891000:
        return 'bajo'
    elif valor >= 6.891000 and valor <= 7.874000:
        return 'medio'
    else:
        return 'alto'
    
df['nivel_desempleo'] = df['desempleo'].apply(lambda x: asignar_valor(x))
df
# Out:
#       tienda       fecha  ventas_semanales  flag_feriado  temperatura  \
# 0          1  05-02-2010        1643690.90             0        42.31
# 1          1  12-02-2010        1641957.44             1        38.51
# 2          1  19-02-2010        1611968.17             0        39.93
# 3          1  26-02-2010        1409727.59             0        46.63
# 4          1  05-03-2010        1554806.68             0        46.50
# ...      ...         ...               ...           ...          ...
# 6430      45  28-09-2012         713173.95             0        64.88
# 6431      45  05-10-2012         733455.07             0        64.89
# 6432      45  12-10-2012         734464.36             0        54.47
# 6433      45  19-10-2012         718125.53             0        56.47
# 6434      45  26-10-2012         760281.43             0        58.85
#
#       precio_combustible         CPI  desempleo dia mes  anio nivel_desempleo
# 0                  2.572  211.096358      8.106  05  02  2010            alto
# 1                  2.548  211.242170      8.106  12  02  2010            alto
# 2                  2.514  211.289143      8.106  19  02  2010            alto
# 3                  2.561  211.319643      8.106  26  02  2010            alto
# 4                  2.625  211.350143      8.106  05  03  2010            alto
# ...                  ...         ...        ...  ..  ..   ...             ...
# 6430               3.997  192.013558      8.684  28  09  2012            alto
# 6431               3.985  192.170412      8.667  05  10  2012            alto
# 6432               4.000  192.327265      8.667  12  10  2012            alto
# 6433               3.969  192.330854      8.667  19  10  2012            alto
# 6434               3.882  192.308899      8.667  26  10  2012            alto
#
# [6435 rows x 12 columns]

# %% [markdown]
# ### 2. Obtenga los descriptivos resumen de la base de datos e identifique las variables numéricas y categóricas. Indique ¿hay algo que le llame la atención?

# %% [markdown]
# En dataset podemos encontrar 11 campos. De ellos, 7 son variables númericas y 4 son categóricas.

# %%
var_cuantitativas = df.select_dtypes('number').columns
print("Variables cuantitativas:")
print(var_cuantitativas)
var_cualitativas  =df.select_dtypes('object').columns
print("Variables cualitativas:")
print(var_cualitativas)

from sklearn.preprocessing import LabelEncoder

# creating instance of labelencoder
labelencoder = LabelEncoder()

df[var_cualitativas] = df[var_cualitativas].apply(labelencoder.fit_transform)
# Out:
# Variables cuantitativas:
# Index(['tienda', 'ventas_semanales', 'flag_feriado', 'temperatura',
#        'precio_combustible', 'CPI', 'desempleo'],
#       dtype='object')
# Variables cualitativas:
# Index(['fecha', 'dia', 'mes', 'anio', 'nivel_desempleo'], dtype='object')

# %% [markdown]
# #### Análisis de valores descriptivos

# %%
df.describe()
# Out:
#             tienda        fecha  ventas_semanales  flag_feriado  temperatura  \
# count  6435.000000  6435.000000      6.435000e+03   6435.000000  6435.000000
# mean     23.000000    71.000000      1.046965e+06      0.069930    60.663782
# std      12.988182    41.282743      5.643666e+05      0.255049    18.444933
# min       1.000000     0.000000      2.099862e+05      0.000000    -2.060000
# 25%      12.000000    35.000000      5.533501e+05      0.000000    47.460000
# 50%      23.000000    71.000000      9.607460e+05      0.000000    62.670000
# 75%      34.000000   107.000000      1.420159e+06      0.000000    74.940000
# max      45.000000   142.000000      3.818686e+06      1.000000   100.140000
#
#        precio_combustible          CPI    desempleo          dia          mes  \
# count         6435.000000  6435.000000  6435.000000  6435.000000  6435.000000
# mean             3.358607   171.578394     7.999151    14.678322     5.447552
# std              0.459020    39.356712     1.875885     8.755780     3.238308
# min              2.472000   126.064000     3.879000     0.000000     0.000000
# 25%              2.933000   131.735000     6.891000     7.000000     3.000000
# 50%              3.445000   182.616521     7.874000    15.000000     5.000000
# 75%              3.735000   212.743293     8.622000    22.000000     8.000000
# max              4.468000   227.232807    14.313000    30.000000    11.000000
#
#               anio  nivel_desempleo
# count  6435.000000      6435.000000
# mean      0.965035         0.763326
# std       0.797019         0.837657
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# 75%       2.000000         2.000000
# max       2.000000         2.000000

# %% [markdown]
# Se observa que las ventas semanales tienen una media de alrededor de 1046965 unidades, con una variabilidad considerable representada por una desviación estándar de aproximadamente 564366 unidades. Además, se puede ver un bajo porcentaje de semanas con feriados de solo el 6.99%, y las condiciones climáticas varían desde temperaturas mínimas de -2.06 grados hasta máximas de 100.14 grados. El precio del combustible tiene un rango de 2472 unidades a 4468 unidades, mientras que el CPI y la tasa de desempleo muestran niveles promedio de 171.58 y 7.99%, respectivamente, con desviaciones estándar que indican cierta variabilidad.

# %% [markdown]
# ### 3. Evalúe si la base contiene datos perdidos.

# %% [markdown]
# Se puede observar que no existen valores nulos o perdidos:

# %%
df.isna().sum()
# Out:
# tienda                0
# fecha                 0
# ventas_semanales      0
# flag_feriado          0
# temperatura           0
# precio_combustible    0
# CPI                   0
# desempleo             0
# dia                   0
# mes                   0
# anio                  0
# nivel_desempleo       0
# dtype: int64

# %% [markdown]
# ### 4. Evalúe si alguna de las variables contiene datos atípicos (outliers). De ser el caso detalle cuáles y qué método estadístico aplicaran para corregir.

# %% [markdown]
# #### Análisis de valores extremos

# %%
# Box plots
fig, axs = plt.subplots(4,2, figsize = (10,10))
plt1 = sns.boxplot(df['tienda'], ax = axs[0,0]).set(xlabel='tienda')
plt2 = sns.boxplot(df['ventas_semanales'], ax = axs[0,1]).set(xlabel='ventas_semanales')
plt3 = sns.boxplot(df['flag_feriado'], ax = axs[1,0]).set(xlabel='flag_feriado')
plt4 = sns.boxplot(df['temperatura'], ax = axs[1,1]).set(xlabel='temperatura')
plt5 = sns.boxplot(df['precio_combustible'], ax = axs[2,0]).set(xlabel='precio_combustible')
plt6 = sns.boxplot(df['CPI'], ax = axs[2,1]).set(xlabel='CPI')
plt7 = sns.boxplot(df['desempleo'], ax = axs[3,0]).set(xlabel='desempleo')

plt.tight_layout()

# %% [markdown]
# De la gráfica de boxplot, podemos ver que las variables donde se requiere el tratamiento de valores extremos son desempleo, temperatura y ventas_semanales.
#
# Para los valores de flag_feriado no será tomado como valores extremos porque representa una variable cualificativa.

# %% [markdown]
# #### Tratamiento de valores atípicos

# %%
# Calculamos el Quartil 1 y Quartil 3 que son aquellos que nos permiten estimar los límites de los datos atípicos
Q1 = df['ventas_semanales'].quantile(0.25)
Q3 = df['ventas_semanales'].quantile(0.75)

print("Q1: ")
print(Q1)
print("Q3: ")
print(Q3)

IQR = Q3 - Q1  #rango intercuartil
print("IQR: ")
print(IQR)

# Ahora removemos aquellas observaciones que se encuentran por fuera del rango: 1.5 x IOR
df = df[~((df['ventas_semanales'] < (Q1 - 1.5 * IQR)) |(df['ventas_semanales'] > (Q3 + 1.5 * IQR)))]
df.shape
# Out:
# Q1:
# 553350.105
# Q3:
# 1420158.66
# IQR:
# 866808.5549999999
# (6401, 12)

# %%
# Calculamos el Quartil 1 y Quartil 3 que son aquellos que nos permiten estimar los límites de los datos atípicos
Q1 = df['desempleo'].quantile(0.25)
Q3 = df['desempleo'].quantile(0.75)

print("Q1: ")
print(Q1)
print("Q3: ")
print(Q3)

IQR = Q3 - Q1  #rango intercuartil
print("IQR: ")
print(IQR)

# Ahora removemos aquellas observaciones que se encuentran por fuera del rango: 1.5 x IOR
df = df[~((df['desempleo'] < (Q1 - 1.5 * IQR)) |(df['desempleo'] > (Q3 + 1.5 * IQR)))]
df.shape
# Out:
# Q1:
# 6.891
# Q3:
# 8.622
# IQR:
# 1.7309999999999999
# (5920, 12)

# %%
# Calculamos el Quartil 1 y Quartil 3 que son aquellos que nos permiten estimar los límites de los datos atípicos
Q1 = df['temperatura'].quantile(0.25)
Q3 = df['temperatura'].quantile(0.75)

print("Q1: ")
print(Q1)
print("Q3: ")
print(Q3)

IQR = Q3 - Q1  #rango intercuartil
print("IQR: ")
print(IQR)

# Ahora removemos aquellas observaciones que se encuentran por fuera del rango: 1.5 x IOR
df = df[~((df['temperatura'] < (Q1 - 1.5 * IQR)) |(df['temperatura'] > (Q3 + 1.5 * IQR)))]
df.shape
# Out:
# Q1:
# 46.965
# Q3:
# 74.7225
# IQR:
# 27.757499999999993
# (5919, 12)

# %% [markdown]
# ### 5. Grafique las distribuciones de las variables y a priori comente sobre ellas.

# %%
sns.distplot(df['tienda'],color="blue")
# Out:
# <Axes: xlabel='tienda', ylabel='Density'>

# %%
sns.distplot(df['ventas_semanales'],color="blue")
# Out:
# <Axes: xlabel='ventas_semanales', ylabel='Density'>

# %%
sns.distplot(df['flag_feriado'],color="blue")
# Out:
# <Axes: xlabel='flag_feriado', ylabel='Density'>

# %%
sns.distplot(df['temperatura'],color="blue")
# Out:
# <Axes: xlabel='temperatura', ylabel='Density'>

# %%
sns.distplot(df['precio_combustible'],color="blue")
# Out:
# <Axes: xlabel='precio_combustible', ylabel='Density'>

# %%
sns.distplot(df['CPI'],color="blue")
# Out:
# <Axes: xlabel='CPI', ylabel='Density'>

# %%
sns.distplot(df['desempleo'],color="blue")
# Out:
# <Axes: xlabel='desempleo', ylabel='Density'>

# %%
sns.distplot(df['nivel_desempleo'],color="blue")
# Out:
# <Axes: xlabel='nivel_desempleo', ylabel='Density'>

# %% [markdown]
# El primer gráfico del campo tienda muestra que una desviación estándar de aproximadamente de 12.98, lo que indica que los números de tienda en los datos tienen cierta variabilidad alrededor de su valor promedio de 23, pero no están extremadamente dispersos.
#
# En el grafico numero dos podemos ver como las ventas semanales tienen una distribución decreciente con picos que suben ocasionalmente, pero podemos ver una tendencia decreciente con el paso del tiempo mientras que en el grafico número tres nos damos cuenta de que las ventas se ven aumentadas cuando existe algún feriado lo cual ayuda mucho a incentivar el consumo y venta de productos en estas fechas.

# %% [markdown]
# ### 6. Obtenga las correlaciones entre los datos de corte numérico

# %%
df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6ca55_row0_col0, #T_6ca55_row1_col1, #T_6ca55_row1_col8, #T_6ca55_row2_col2, #T_6ca55_row3_col3, #T_6ca55_row4_col4, #T_6ca55_row5_col5, #T_6ca55_row6_col6, #T_6ca55_row7_col7, #T_6ca55_row8_col1, #T_6ca55_row8_col8, #T_6ca55_row9_col9, #T_6ca55_row10_col10, #T_6ca55_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col1, #T_6ca55_row0_col8, #T_6ca55_row6_col1, #T_6ca55_row7_col5, #T_6ca55_row10_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col2, #T_6ca55_row2_col0, #T_6ca55_row2_col1, #T_6ca55_row2_col8, #T_6ca55_row3_col4, #T_6ca55_row4_col3, #T_6ca55_row6_col5, #T_6ca55_row7_col6, #T_6ca55_row7_col10, #T_6ca55_row7_col11, #T_6ca55_row10_col9, #T_6ca55_row11_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col4, #T_6ca55_row2_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col5, #T_6ca55_row0_col9, #T_6ca55_row1_col4, #T_6ca55_row11_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_6ca55_row0_col10, #T_6ca55_row2_col9, #T_6ca55_row11_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6ca55_row0_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col0, #T_6ca55_row3_col0, #T_6ca55_row8_col0, #T_6ca55_row11_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6ca55_row1_col2, #T_6ca55_row8_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col3, #T_6ca55_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col5, #T_6ca55_row3_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col6, #T_6ca55_row8_col6, #T_6ca55_row9_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col7, #T_6ca55_row1_col11, #T_6ca55_row3_col11, #T_6ca55_row8_col7, #T_6ca55_row8_col11, #T_6ca55_row9_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6ca55_row1_col9, #T_6ca55_row7_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6ca55_row1_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_6ca55_row2_col3, #T_6ca55_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6ca55_row2_col4, #T_6ca55_row9_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6ca55_row2_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6ca55_row2_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6ca55_row2_col10, #T_6ca55_row3_col6, #T_6ca55_row6_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6ca55_row2_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_6ca55_row3_col1, #T_6ca55_row3_col8, #T_6ca55_row5_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6ca55_row3_col2, #T_6ca55_row5_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6ca55_row3_col5, #T_6ca55_row4_col8, #T_6ca55_row5_col6, #T_6ca55_row5_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6ca55_row3_col7, #T_6ca55_row4_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_6ca55_row3_col9, #T_6ca55_row5_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_6ca55_row4_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6ca55_row4_col1, #T_6ca55_row9_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6ca55_row4_col2, #T_6ca55_row6_col7, #T_6ca55_row10_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6ca55_row4_col5, #T_6ca55_row9_col0, #T_6ca55_row10_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6ca55_row4_col7, #T_6ca55_row11_col10 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_6ca55_row4_col9 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_6ca55_row4_col10, #T_6ca55_row6_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6ca55_row4_col11 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6ca55_row5_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6ca55_row5_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6ca55_row5_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6ca55_row5_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6ca55_row5_col10 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_6ca55_row5_col11 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_6ca55_row6_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6ca55_row6_col3, #T_6ca55_row11_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6ca55_row6_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_6ca55_row6_col8, #T_6ca55_row9_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6ca55_row6_col9, #T_6ca55_row8_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6ca55_row6_col11 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_6ca55_row7_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_6ca55_row7_col1, #T_6ca55_row7_col8, #T_6ca55_row11_col1, #T_6ca55_row11_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6ca55_row7_col3, #T_6ca55_row7_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6ca55_row8_col4, #T_6ca55_row8_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6ca55_row8_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6ca55_row9_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_6ca55_row9_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6ca55_row9_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6ca55_row9_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6ca55_row9_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_6ca55_row10_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6ca55_row10_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_6ca55_row10_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6ca55_row10_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_6ca55_row10_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6ca55_row10_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6ca55_row10_col11 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_6ca55_row11_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6ca55_row11_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_6ca55_row11_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# </style>
# <table id="T_6ca55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ca55_level0_col0" class="col_heading level0 col0" >tienda</th>
#       <th id="T_6ca55_level0_col1" class="col_heading level0 col1" >fecha</th>
#       <th id="T_6ca55_level0_col2" class="col_heading level0 col2" >ventas_semanales</th>
#       <th id="T_6ca55_level0_col3" class="col_heading level0 col3" >flag_feriado</th>
#       <th id="T_6ca55_level0_col4" class="col_heading level0 col4" >temperatura</th>
#       <th id="T_6ca55_level0_col5" class="col_heading level0 col5" >precio_combustible</th>
#       <th id="T_6ca55_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_6ca55_level0_col7" class="col_heading level0 col7" >desempleo</th>
#       <th id="T_6ca55_level0_col8" class="col_heading level0 col8" >dia</th>
#       <th id="T_6ca55_level0_col9" class="col_heading level0 col9" >mes</th>
#       <th id="T_6ca55_level0_col10" class="col_heading level0 col10" >anio</th>
#       <th id="T_6ca55_level0_col11" class="col_heading level0 col11" >nivel_desempleo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ca55_level0_row0" class="row_heading level0 row0" >tienda</th>
#       <td id="T_6ca55_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6ca55_row0_col1" class="data row0 col1" >0.003933</td>
#       <td id="T_6ca55_row0_col2" class="data row0 col2" >-0.319365</td>
#       <td id="T_6ca55_row0_col3" class="data row0 col3" >0.004298</td>
#       <td id="T_6ca55_row0_col4" class="data row0 col4" >-0.026907</td>
#       <td id="T_6ca55_row0_col5

# %%
# Número de las variables
n = 12
fig = plt.figure(figsize=(20,30))
# Correlaciones en pares
corr = df.corr(numeric_only=True)
#
cols = corr.nlargest(12, "ventas_semanales")["ventas_semanales"].index
# Calculate correlation
for i in np.arange(1,11):
        regline = df[cols[i]]
        ax = fig.add_subplot(7,2,i)
        sns.regplot(x=regline, y=df['ventas_semanales'], scatter_kws={"color": "royalblue", "s": 3},
                    line_kws={"color": "turquoise"})
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Comente que variable escogerán como variable dependiente y que variables introducirán a su modelo.

# %% [markdown]
# Nuestra variable dependiente será ventas_semanales y las variables independientes serán los demás campos.

# %% [markdown]
# ### 8. Indique que tipo de modelación realizarán y porqué.

# %% [markdown]
# Dado que los datos de panel consisten en información recopilada a lo largo del tiempo para uno o más individuos o "casos" identificables de manera única, se llevará a cabo un análisis de panel. Esto se debe a que podemos agrupar las ventas semanales por tiendas y también agruparlas en intervalos de tiempo, como en este caso, anualmente.

# %% [markdown]
# ### 9. Verifique los supuestos, de haber escogido el enfoque econométrico.

# %% [markdown]
# ### 10. Obtenga el modelo definitivo, prediga los valores y comente el grado de ajuste del modelo. Justifique con métricas su respuesta.

# %% [markdown]
# #### Separamos a los predictores de nuestra variable objetivo

# %%
X = df[df.columns.difference(['fecha', 'ventas_semanales', 'flag_feriado', 'desempleo', 'dia', 'mes', 'anio'])]
y = df.ventas_semanales

X
# Out:
#              CPI  nivel_desempleo  precio_combustible  temperatura  tienda
# 0     211.096358                0               2.572        42.31       1
# 1     211.242170                0               2.548        38.51       1
# 2     211.289143                0               2.514        39.93       1
# 3     211.319643                0               2.561        46.63       1
# 4     211.350143                0               2.625        46.50       1
# ...          ...              ...                 ...          ...     ...
# 6430  192.013558                0               3.997        64.88      45
# 6431  192.170412                0               3.985        64.89      45
# 6432  192.327265                0               4.000        54.47      45
# 6433  192.330854                0               3.969        56.47      45
# 6434  192.308899                0               3.882        58.85      45
#
# [5919 rows x 5 columns]

# %% [markdown]
# #### Entrenar el modelo con los datos de entrenamiento

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.20, random_state =123)

print(X_train.shape,"",type(X_train))
print(y_train.shape,"\t ",type(y_train))
print(X_test.shape,"",type(X_test))
print(y_test.shape,"\t ",type(y_test))
# Out:
# (4735, 5)  <class 'pandas.core.frame.DataFrame'>
# (4735,) 	  <class 'pandas.core.series.Series'>
# (1184, 5)  <class 'pandas.core.frame.DataFrame'>
# (1184,) 	  <class 'pandas.core.series.Series'>

# %%
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Realizar las predicciones

# %%
predicciones_train = modelo_regresion.predict(X_train)
predicciones_test = modelo_regresion.predict(X_test)

# %% [markdown]
# #### Métricas de evaluación

# %% [markdown]
# ##### MSE

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

MSE_train = mean_squared_error(y_train, predicciones_train)
MSE_test = mean_squared_error(y_test, predicciones_test)
print(MSE_train)
print(MSE_test)
# Out:
# 264231635062.3661
# 272702489423.2251

# %% [markdown]
# ##### RMSE

# %%
RMSE_train = np.sqrt(MSE_train)
RMSE_test = np.sqrt(MSE_test)
print(RMSE_train)
print(RMSE_test)
# Out:
# 514034.6632887378
# 522209.239120896

# %% [markdown]
# ##### MAE

# %%
MAE_train = mean_absolute_error(y_train, predicciones_train)
MAE_test = mean_absolute_error(y_test, predicciones_test)
print(MAE_train)
print(MAE_test)
# Out:
# 430086.4007050033
# 437165.015533291

# %% [markdown]
# ##### R^2

# %%
from sklearn.metrics import r2_score

r_square_train = r2_score(y_train, predicciones_train)
r_square_test  = r2_score(y_test, predicciones_test)
print('El R^2 del subconjunto de entrenamiento es:' , r_square_train)
print('El R^2 del subconjunto de prueba es:' , r_square_test)
# Out:
# El R^2 del subconjunto de entrenamiento es: 0.12789004394852777
# El R^2 del subconjunto de prueba es: 0.12188228179284866

# %%
# Print the Intercept:
print('intercepto:', modelo_regresion.intercept_)

# Print the Slope:
print('pendiente:', modelo_regresion.coef_)
# Out:
# intercepto: 1793918.1658189693
# pendiente: [ -2336.47296008  29700.76014974  -2373.24215544   -562.13525727
#  -14358.7446012 ]

# %% [markdown]
# ### 11. Grafique a los valores predicho de modelo vs los valores reales.
# - ¿Cómo se ven una vez graficados frente a los valores reales? Argumente su respuesta.

# %% [markdown]
# #### Predicciones es el subgrupo de datos de entrenamiento

# %%
fig, ax = plt.subplots()
ax.plot(y_train.values)
ax.plot(predicciones_train)
plt.title("Valores observados vs. predichos en train set");

# %% [markdown]
# #### Predicciones es el subgrupo de datos de prueba

# %%
fig, ax = plt.subplots()
ax.plot(y_test.values)
ax.plot(predicciones_test)
plt.title("Valores observados vs. predichos en test set");

# %% [markdown]
# ### 12. Concluya sobre su modelo. Para ello, si escogió el enfoque econométrico, interprete coeficientes, por el contrario si escogió el enfoque de machine learning, determine cuáles son las variables que tienen mayor poder explicativo sobre su variable objetivo.

# %% [markdown]
# ### 13. Suba su proyecto final en su cuenta de Github y adjunte una captura de pantalla en esta plataforma.

# %% [markdown]
# ![image.png](attachment:image.png)
